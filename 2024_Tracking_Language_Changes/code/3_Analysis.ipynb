# %% [markdown]
# # Analysis
#
#
#
# ## Get ready
#
# As always, we start with a couple of code cells that load up and nickname some useful packages, then check file locations, then import files and check them.

# %%
import os                         # os is a module for navigating your machine (e.g., file directories).
import pandas as pd

# %%
print(os.listdir("..\\output\\final")  )                                # check 'results' folder is not empty/has correct stuff
# Out:
# ['target_words_by_year.csv']

# %% [markdown]
# ## Import
#
# Having checked the contents of the output folder and seen the files we expected to see, we can now import and check them.

# %%
target_words_by_year = pd.read_csv('..\\output\\final\\target_words_by_year.csv')   # start importing the file

# %%
target_words_by_year
# Out:
#     Unnamed: 0  set          words  2001  2002  2003  2004  2005  2006  2007  \
# 0            0    1       mutation  3035  2009  1567  2192  2595  2571  2243
# 1            1    1        variant   295   164   152   136   294   266   308
# 2            2    2        disease  1343   765   572   615  1002  1045   925
# 3            3    2       disorder   654   436   310   337   560   587   521
# 4            4    2        illness    15    11     3     9     3     9     7
# 5            5    2      condition   203   132    72    95   130   183   136
# 6            6    2      diagnosis   655   488   287   366   485   497   414
# 7            7    2       syndrome  1078   673   499   838   835   900   885
# 8            8    3        patient  2778  1763  1572  1900  2634  2456  2415
# 9            9    3     individual   658   320   286   186   384   499   445
# 10          10    3         person    88    44    42     7    52    91    83
# ...

# %% [markdown]
# ## Plot some things

# %%
set_1 = target_words_by_year[target_words_by_year.set == 1]               # data frame with only the rows matching each set
set_2 = target_words_by_year[target_words_by_year.set == 2]              
set_3 = target_words_by_year[target_words_by_year.set == 3]              
set_4 = target_words_by_year[target_words_by_year.set == 4]              
set_5 = target_words_by_year[target_words_by_year.set == 5]

# %%
set_1.plot()                          # create a plot from the combined, re-indexed and renamed data frame
plt.legend(frameon=False)         # Set position for legend and set legend frame to be false
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 set_1.plot()                          # create a plot from the combined, re-indexed and renamed data frame
# ----> 2 plt.legend(frameon=False)         # Set position for legend and set legend frame to be false
#       3 plt.show()
#
# NameError: name 'plt' is not defined
