# %% [markdown]
# # Analysis
#
#
#
# ## Get ready
#
# As always, we start with a couple of code cells that load up and nickname some useful packages, then check file locations, then import files and check them.

# %%
import os                         # os is a module for navigating your machine (e.g., file directories).
import pandas as pd
import statistics
import re                         # things we need for RegEx corrections
import matplotlib.pyplot as plt
import string

# %%
print(os.listdir("..\\output\\final")  )                                # check 'results' folder is not empty/has correct stuff
# Out:
# ['target_words_by_year.csv']

# %% [markdown]
# ## Import
#
# Having checked the contents of the output folder and seen the files we expected to see, we can now import and check them.

# %%
target_words_by_year = pd.read_csv('..\\output\\final\\target_words_by_year.csv')   # start importing the file

# %%
target_words_by_year = target_words_by_year.drop(['Unnamed: 0'], axis=1)
target_words_by_year.head(5)                                         # check it again
# Out:
#    set           words    2001  2002    2003    2004    2005  2006    2007  \
# 0    1        mutation  3035.0  2009  1567.0  2192.0  2595.0  2571  2243.0
# 1    1         variant   295.0   164   152.0   136.0   294.0   266   308.0
# 2    1      genechange     NaN     1     NaN     NaN     NaN     1     NaN
# 3    1  genealteration     5.0     2     1.0     NaN     4.0     1     2.0
# 4    2         disease  1343.0   765   572.0   615.0  1002.0  1045   925.0
#
#      2008  ...    2012    2013  2014  2015    2016    2017  2018    2019  \
# 0  2885.0  ...  2802.0  4090.0  3708  3241  3194.0  2710.0  2247  1797.0
# 1   484.0  ...   750.0  1268.0  1436  1492  2124.0  1633.0  2071  2765.0
# 2     1.0  ...     NaN     NaN     1     1     NaN     NaN     1     NaN
# 3     NaN  ...     NaN     6.0     2     2     3.0     1.0     3     2.0
# 4  1199.0  ...  1086.0  1619.0  1646  1509  1437.0  1197.0  1213  1453.0
#
#      2020  2021
# 0  2011.0  1807
# 1  3653.0  4755
# 2     NaN     1
# ...

# %%
melted_words = pd.melt(target_words_by_year, 
                 id_vars=['set', 'words'], 
                 value_vars=['2001', '2002', '2003', '2004','2005', '2006','2007', '2008','2009', '2010',
                            '2011', '2012', '2013','2014', '2015','2016', '2017','2018', '2019', '2020', '2021'],
                      var_name = 'Year', 
                      value_name = 'Count')

melted_words.set_index('Year', inplace=True)
print(list(melted_words.columns))
# Out:
# ['set', 'words', 'Count']

# %% [markdown]
# ## Plot some things

# %%
set_1 = melted_words[melted_words.set == 1]               # data frame with only the rows matching each set

set_1.groupby('words')['Count'].plot(legend=True)

set_1.plot(x = 'Year', y = 'Count')
plt.legend(frameon=False)                                                        # 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# ...

# %%
set_2 = melted_words[melted_words.set == 2]               # data frame with only the rows matching each set

set_2.groupby('words')['Count'].plot(legend=True)

set_2.plot(x = 'Year', y = 'Count')
plt.legend(frameon=False)                                                        # 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# ...

# %%
set_3 = melted_words[melted_words.set == 3]               # data frame with only the rows matching each set

set_3.groupby('words')['Count'].plot(legend=True)

set_3.plot(x = 'Year', y = 'Count')
plt.legend(frameon=False)                                                        # 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# ...

# %%
set_4 = melted_words[melted_words.set == 4]               # data frame with only the rows matching each set

set_4.groupby('words')['Count'].plot(legend=True)

set_4.plot(x = 'Year', y = 'Count')
plt.legend(frameon=False)                                                        # 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# ...

# %%
set_5 = melted_words[melted_words.set == 5]               # data frame with only the rows matching each set

set_5.groupby('words')['Count'].plot(legend=True)

set_5.plot(x = 'Year', y = 'Count')
plt.legend(frameon=False)                                                        # 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# ...

# %%
big_words_1 = ['mutation', 'variant']
little_words_1 = ['genechange', 'genealteration']

set_1_big = melted_words[melted_words['words'].isin(big_words_1)]
set_1_little = melted_words[melted_words['words'].isin(little_words_1)]

print(set_1_big)
# Out:
#       set     words   Count
# Year
# 2001    1  mutation  3035.0
# 2001    1   variant   295.0
# 2002    1  mutation  2009.0
# 2002    1   variant   164.0
# 2003    1  mutation  1567.0
# 2003    1   variant   152.0
# 2004    1  mutation  2192.0
# 2004    1   variant   136.0
# 2005    1  mutation  2595.0
# 2005    1   variant   294.0
# 2006    1  mutation  2571.0
# 2006    1   variant   266.0
# 2007    1  mutation  2243.0
# 2007    1   variant   308.0
# 2008    1  mutation  2885.0
# 2008    1   variant   484.0
# 2009    1  mutation  2567.0
# 2009    1   variant   556.0
# 2010    1  mutation  2430.0
# 2010    1   variant   514.0
# 2011    1  mutation  3254.0
# 2011    1   variant   810.0
# 2012    1  mutation  2802.0
# 2012    1   variant   750.0
# 2013    1  mutation  4090.0
# 2013    1   variant  1268.0
# 2014    1  mutation  3708.0
# 2014    1   variant  1436.0
# 2015    1  mutation  3241.0
# 2015    1   variant  1492.0
# 2016    1  mutation  3194.0
# 2016    1   variant  2124.0
# ...

# %%
set_1_big.groupby('words')['Count'].plot(legend=True)

set_1_big.plot(x = 'Year', y = 'Count')
plt.legend(frameon=False)                                                        # 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# ...

# %%
set_1_little.groupby('words')['Count'].plot(legend=True)

set_1_little.plot(x = 'Year', y = 'Count')
plt.legend(frameon=False)                                                        # 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# ...

# %%
set_1 = target_words_by_year[target_words_by_year.set == 1]               # data frame with only the rows matching each set
set_2 = target_words_by_year[target_words_by_year.set == 2]              
set_3 = target_words_by_year[target_words_by_year.set == 3]              
set_4 = target_words_by_year[target_words_by_year.set == 4]              
set_5 = target_words_by_year[target_words_by_year.set == 5]

# %%
print(set_1)
print(list(set_1.columns))
# Out:
#    set           words    2001  2002    2003    2004    2005  2006    2007  \
# 0    1        mutation  3035.0  2009  1567.0  2192.0  2595.0  2571  2243.0
# 1    1         variant   295.0   164   152.0   136.0   294.0   266   308.0
# 2    1      genechange     NaN     1     NaN     NaN     NaN     1     NaN
# 3    1  genealteration     5.0     2     1.0     NaN     4.0     1     2.0
#
#      2008  ...    2012    2013  2014  2015    2016    2017  2018    2019  \
# 0  2885.0  ...  2802.0  4090.0  3708  3241  3194.0  2710.0  2247  1797.0
# 1   484.0  ...   750.0  1268.0  1436  1492  2124.0  1633.0  2071  2765.0
# 2     1.0  ...     NaN     NaN     1     1     NaN     NaN     1     NaN
# 3     NaN  ...     NaN     6.0     2     2     3.0     1.0     3     2.0
#
#      2020  2021
# 0  2011.0  1807
# 1  3653.0  4755
# 2     NaN     1
# 3     2.0     3
#
# [4 rows x 23 columns]
# ...

# %%
set_1b.groupby("words").plot(x='variable', y='value')   # create a plot from the combined, re-indexed and renamed data frame
plt.legend(frameon=False)                               # Set position for legend and set legend frame to be false
plt.show()
